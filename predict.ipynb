# %%
# !pip install transformers -q

# %%
# !python predict.py --model-path ./checkpoint-600
# Out:
# Загрузка модели из ./checkpoint-600...
# Loading weights: 100% 201/201 [00:00<00:00, 4155.58it/s]
# Токенизатор: bert-base-uncased
# config.json: 100% 570/570 [00:00<00:00, 2.09MB/s]
# ...
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 182kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 2.12MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 5.03MB/s]
# Классы модели: ['Fantasy', 'History', 'Nonfiction', 'Romance', 'Sequential Art']
# Устройство: cpu
#
# === Примеры ===
#
# [Пример 1] (ожидаемый жанр: Fantasy)
#
# --- Аннотация ---
# A young orphan discovers he is a wizard and enters a school of magic where he must face a dark lord threatening the world.
#
# --- Предсказание ---
#   1. Fantasy: 96.2%
#   2. Sequential Art: 1.5%
#   3. Romance: 0.9%
#
# [Пример 2] (ожидаемый жанр: History)
#
# --- Аннотация ---
# This biography explores the life of a 19th-century emperor, covering wars, political reforms, and the fall of an empire.
#
# --- Предсказание ---
#   1. History: 97.7%
# ...
